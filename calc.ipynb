# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
arr = np.arange(0,4)
arr1 = np.vstack([arr.copy(), arr.copy()])
plt.figure(dpi=1200)
fig = plt.pcolor(arr1,cmap = 'hot')
cb = plt.colorbar(fig)
plt.savefig('hotcb.svg')
